# %%
import sys

sys.path.append("../")
sys.path.append("../src/")

# %%
import torch

from src.models import *
from src.datasets.image_size import model2size

# %%
model_name = ""

# %%
if model_name != "":
    model = get_model(model_name, 122, 2, 11)
    sample = torch.randn(1, 3, model2size[model_name], model2size[model_name])
    model.eval()

# %%
if model_name != "":
    print(model(sample)[0].shape)

# %%
print(model2size)
